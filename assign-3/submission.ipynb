# %%
import pandas as pd

ty = pd.read_excel("trend.xlsx", sheet_name=2)
uro = pd.read_excel("trend.xlsx", sheet_name=0)
sp = pd.read_excel("trend.xlsx", sheet_name=1)

# %%
ty
# Out:
#            #ty  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4 Unnamed: 5  \
# 0        #Date        Open        High         Low       Close         NC
# 1     19990308   114.46875    114.6875     114.375    114.4375    0.09375
# 2     19990309      114.25     115.125     114.125         115     0.5625
# 3     19990310   115.03125     115.125    114.6875     114.875     -0.125
# 4     19990311   114.78125   115.09375     114.625     114.875          0
# ...        ...         ...         ...         ...         ...        ...
# 2979  20101227   119.28125  119.953125   119.21875    119.9375     0.4062
# 2980  20101228   120.03125    120.1875  118.953125  119.046875    -0.8906
# 2981  20101229   119.03125  120.265625  118.953125      120.25     1.2031
# 2982  20101230         120  120.203125  119.578125  119.984375    -0.2656
# 2983  20101231  120.359375  120.484375    119.9375   120.34375     0.3594
#
#      Unnamed: 6 Unnamed: 7       SynTY  \
# ...

# %%
ty = ty.rename(columns={
    '#ty': 'Date', 'Unnamed: 1': 'Open', 'Unnamed: 2': 'High',
    'Unnamed: 3': 'Low', 'Unnamed: 4': 'Close', 'Unnamed: 5': 'NC','Unnamed: 6': 'PC%', 
    'Unnamed: 7': 'Roll', 'Unnamed: 8': 'SynTY', 'M  O   V   I   N   G   A   V   E   R   A   G   E  S': 'ma10'
})

# %%
ty
# Out:
#           Date        Open        High         Low       Close       NC  \
# 0        #Date        Open        High         Low       Close       NC
# 1     19990308   114.46875    114.6875     114.375    114.4375  0.09375
# 2     19990309      114.25     115.125     114.125         115   0.5625
# 3     19990310   115.03125     115.125    114.6875     114.875   -0.125
# 4     19990311   114.78125   115.09375     114.625     114.875        0
# ...        ...         ...         ...         ...         ...      ...
# 2979  20101227   119.28125  119.953125   119.21875    119.9375   0.4062
# 2980  20101228   120.03125    120.1875  118.953125  119.046875  -0.8906
# 2981  20101229   119.03125  120.265625  118.953125      120.25   1.2031
# 2982  20101230         120  120.203125  119.578125  119.984375  -0.2656
# 2983  20101231  120.359375  120.484375    119.9375   120.34375   0.3594
#
#            PC% Unnamed: 7       SynTY  ma10  ... THESE ARE FOR BREAKOUT   \
# ...
