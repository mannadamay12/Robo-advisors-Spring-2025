# %%
import pandas as pd

df = pd.read_excel("counter.xlsx")

# %%
df
# Out:
#            #sp DAILY                                    OHLC Unnamed: 2  \
# 0        #Date                                          Open       High
# 1     20030701                                         968.5  982.29999
# 2     20030702                                           983  993.79999
# 3     20030703                                     986.20001  994.20001
# 4     20030707                                         992.5       1005
# ...        ...                                           ...        ...
# 4490  20210129                                       3760.75    3770.25
# 4491  20210201                                        3741.5       3777
# 4492  20210202                                       3799.25    3835.75
# 4493  20210203                                        3828.5       3840
# 4494  20210204                                       3834.25     3868.5
#
#      Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# ...
